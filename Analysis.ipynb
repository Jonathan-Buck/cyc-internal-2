# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = "./trial.csv"

# %%
df_ag = pd.read_csv("aggregate")

# %%
df = pd.read_csv(filename)

# %%
def GPA(data):
    sns.histplot(data = data, x = "GPA", kde=True, legend=False, bins = 20)

# %% [markdown]
# ## GPA Analysis

# %%
GPA(df_nonzero)

# %%
GPA(df_ag_nonzero)

# %%
df_nonzero = df.replace(0, np.nan)
df_ag_nonzero = df_ag.replace(0, np.nan)
